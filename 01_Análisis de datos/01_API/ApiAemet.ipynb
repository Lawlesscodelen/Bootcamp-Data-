# %%
import requests
import json

# %%
api_key = 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJlbXNnOTRAZ21haWwuY29tIiwianRpIjoiMTY1N2FlOWItNTExYy00Y2FjLTljMGMtNzljZTg2YjE3MjZiIiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE1ODM0OTQzNDEsInVzZXJJZCI6IjE2NTdhZTliLTUxMWMtNGNhYy05YzBjLTc5Y2U4NmIxNzI2YiIsInJvbGUiOiIifQ.TjMpJc94DbOJSZPu9nsYio3eTShJr4YNPecsLyxpIGY'

# %%
url = 'https://opendata.aemet.es/opendata'
estaciones = '/api/valores/climatologicos/inventarioestaciones/todasestaciones'

# %%
response = requests.get(url + estaciones, params={'api_key': api_key})

# %%
response.status_code
# Out:
# 200

# %%
resp_dict = json.loads(response.text)

# %%
resp_dict
# Out:
# {'descripcion': 'exito',
#  'estado': 200,
#  'datos': 'https://opendata.aemet.es/opendata/sh/1be567c9',
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/0556af7a'}

# %%
response2 = requests.get(resp_dict.get('metadatos'), params={'api_key': api_key})

# %%
response3 = requests.get(resp_dict.get('datos'), params={'api_key': api_key})

# %%
dict_estaciones = json.loads(response3.text)

# %%
est_madrid = [estacion for estacion in dict_estaciones if estacion.get('provincia') == 'MADRID']

# %%
est_madrid
# Out:
# [{'latitud': '404735N',
#   'provincia': 'MADRID',
#   'altitud': '1894',
#   'indicativo': '2462',
#   'nombre': 'PUERTO DE NAVACERRADA',
#   'indsinop': '08215',
#   'longitud': '040038W'},
#  {'latitud': '400402N',
#   'provincia': 'MADRID',
#   'altitud': '540',
#   'indicativo': '3100B',
#   'nombre': 'ARANJUEZ',
#   'indsinop': '08229',
#   'longitud': '033246W'},
#  {'latitud': '410025N',
#   'provincia': 'MADRID',
#   'altitud': '1030',
#   'indicativo': '3110C',
#   'nombre': 'BUITRAGO DEL LOZOYA',
#   'indsinop': '08146',
#   'longitud': '033649W'},
#  {'latitud': '404146N',
#   'provincia': 'MADRID',
#   'altitud': '1004',
#   'indicativo': '3191E',
#   'nombre': 'COLMENAR VIEJO',
#   'indsinop': '08219',
#   'longitud': '034554W'},
#  {'latitud': '401758N',
#   'provincia': 'MADRID',
#   'altitud': '620',
#   'indicativo': '3200',
#   'nombre': 'GETAFE',
#   'indsinop': '08224',
#   'longitud': '034320W'},
#  {'latitud': '402800N',
#   'provincia': 'MADRID',
# ...

# %%
nav = est_madrid[0]

# %%
nav
# Out:
# {'latitud': '404735N',
#  'provincia': 'MADRID',
#  'altitud': '1894',
#  'indicativo': '2462',
#  'nombre': 'PUERTO DE NAVACERRADA',
#  'indsinop': '08215',
#  'longitud': '040038W'}

# %%
idema = nav.get('indsinop')

# %%
idema
# Out:
# '08215'

# %%
clim = f'/api/observacion/convencional/datos/estacion/{idema}'

# %%
clim
# Out:
# '/api/observacion/convencional/datos/estacion/08215'

# %%
response4 = requests.get(url+clim, params= {'api_key': api_key})

# %%
json.loads(response4.text)
# Out:
# {'descripcion': 'No hay datos que satisfagan esos criterios', 'estado': 404}

# %%
idema = nav.get('indicativo')

# %%
idema
# Out:
# '2462'

# %%
clim = f'/api/observacion/convencional/datos/estacion/{idema}'

# %%
clim
# Out:
# '/api/observacion/convencional/datos/estacion/2462'

# %%
response5 = requests.get(url+clim, params={'api_key': api_key})

# %%
predata = json.loads(response5.text)

# %%
response6 = requests.get(predata['metadatos'], params={'api_key': api_key})

# %%
json.loads(response6.text)
# Out:
# {'unidad_generadora': 'Servicio de Observación',
#  'periodicidad': 'continuamente',
#  'formato': 'application/json',
#  'copyright': '© AEMET. Autorizado el uso de la información y su reproducción citando a AEMET como autora de la misma.',
#  'notaLegal': 'http://www.aemet.es/es/nota_legal',
#  'campos': [{'id': 'idema',
#    'descripcion': 'Indicativo climatógico de la estación meteorológia automática',
#    'tipo_datos': 'string',
#    'requerido': True},
#   {'id': 'lon',
#    'descripcion': 'Longitud de la estación meteorológica (grados)',
#    'tipo_datos': 'float',
#    'requerido': True},
#   {'id': 'lat',
#    'descripcion': 'Latitud de la estación meteorológica (grados)',
#    'tipo_datos': 'float',
#    'requerido': True},
#   {'id': 'alt',
#    'descripcion': 'Altitud de la estación en metros',
#    'tipo_datos': 'float',
#    'requerido': True},
#   {'id': 'ubi',
#    'descripcion': 'Ubicación de la estación. Nombre de la estación',
#    'tipo_datos': 'string',
# ...

# %%
resp7 = requests.get(predata['datos'], params={'api_key': api_key})

# %%
datos = json.loads(resp7.text)

# %%
datos
# Out:
# [{'idema': '2462',
#   'lon': -4.010556,
#   'fint': '2020-03-11T20:00:00',
#   'prec': 0.0,
#   'alt': 1894.0,
#   'vmax': 1.9,
#   'vv': 0.6,
#   'dv': 197.0,
#   'lat': 40.793056,
#   'dmax': 316.0,
#   'ubi': 'NAVACERRADA PUERTO',
#   'pres': 819.1,
#   'hr': 55.0,
#   'stdvv': 0.4,
#   'ts': 8.6,
#   'tamin': 11.8,
#   'ta': 11.8,
#   'tamax': 12.3,
#   'tpr': 3.0,
#   'vis': 20.0,
#   'stddv': 27.0,
#   'inso': 0.0,
#   'tss5cm': 8.6,
#   'vmaxu': 1.9,
#   'dvu': 193.0,
#   'pacutp': 0.0,
#   'vvu': 0.6,
#   'stdvvu': 0.5,
#   'stddvu': 27.0,
#   'dmaxu': 315.0,
#   'tss20cm': 8.1,
#   'geo850': {'value': 1577.0, 'present': True},
#   'nieve': 0.0},
#  {'idema': '2462',
#   'lon': -4.010556,
#   'fint': '2020-03-11T21:00:00',
#   'prec': 0.0,
#   'alt': 1894.0,
#   'vmax': 1.8,
#   'vv': 0.8,
#   'dv': 58.0,
#   'lat': 40.793056,
#   'dmax': 321.0,
#   'ubi': 'NAVACERRADA PUERTO',
#   'pres': 819.3,
#   'hr': 56.0,
#   'stdvv': 0.3,
#   'ts': 8.3,
#   'tamin': 11.4,
# ...

# %%
mediciones = list()
for estacion_de_madrid in est_madrid:
    idema = estacion_de_madrid.get('indicativo')
    clim = f'/api/observacion/convencional/datos/estacion/{idema}'
    resp = json.loads(requests.get(url+clim, params={'api_key': api_key}).text)
    if resp.get('estado') == 200:
        datos = json.loads(requests.get(resp['datos'], params={'api_key': api_key}).text)
        mediciones.append(datos)

# %%
mediciones
# Out:
# [[{'idema': '2462',
#    'lon': -4.010556,
#    'fint': '2020-03-11T20:00:00',
#    'prec': 0.0,
#    'alt': 1894.0,
#    'vmax': 1.9,
#    'vv': 0.6,
#    'dv': 197.0,
#    'lat': 40.793056,
#    'dmax': 316.0,
#    'ubi': 'NAVACERRADA PUERTO',
#    'pres': 819.1,
#    'hr': 55.0,
#    'stdvv': 0.4,
#    'ts': 8.6,
#    'tamin': 11.8,
#    'ta': 11.8,
#    'tamax': 12.3,
#    'tpr': 3.0,
#    'vis': 20.0,
#    'stddv': 27.0,
#    'inso': 0.0,
#    'tss5cm': 8.6,
#    'vmaxu': 1.9,
#    'dvu': 193.0,
#    'pacutp': 0.0,
#    'vvu': 0.6,
#    'stdvvu': 0.5,
#    'stddvu': 27.0,
#    'dmaxu': 315.0,
#    'tss20cm': 8.1,
#    'geo850': {'value': 1577.0, 'present': True},
#    'nieve': 0.0},
#   {'idema': '2462',
#    'lon': -4.010556,
#    'fint': '2020-03-11T21:00:00',
#    'prec': 0.0,
#    'alt': 1894.0,
#    'vmax': 1.8,
#    'vv': 0.8,
#    'dv': 58.0,
#    'lat': 40.793056,
#    'dmax': 321.0,
#    'ubi': 'NAVACERRADA PUERTO',
#    'pres': 819.3,
#    'hr': 56.0,
# ...

# %%
requests.post()
